# %% [markdown]
# # 🚀 Notebook de Exemplo
# Este é um notebook inicial rodando no **GitHub Codespaces**.
# Aqui você pode programar em Python sem instalar nada no seu computador.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Hello, Codespaces! 🚀")

# %%
# Exemplo: gráfico simples
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Senoide no Codespaces")
plt.show()
